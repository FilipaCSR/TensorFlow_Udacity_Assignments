# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# %matplotlib inline
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  f = zipfile.ZipFile(filename)
  for name in f.namelist():
    return tf.compat.as_str(f.read(name)).split()
  f.close()
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# ('Most common words (+UNK)', [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)])
# ('Sample data', [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156])

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# ('data:', ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first'])
#
# with num_skips = 2 and skip_window = 1:
# ('    batch:', ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term'])
# ('    labels:', ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'of', 'a'])
#
# with num_skips = 4 and skip_window = 2:
# ('    batch:', ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a'])
# ('    labels:', ['a', 'anarchism', 'term', 'originated', 'of', 'term', 'as', 'originated'])

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.195351
# Nearest to history: transubstantiation, austrasia, franchised, average, glue, benetton, mede, encyclop,
# Nearest to had: touching, bef, granger, randomization, congratulate, guitarist, barriers, physiological,
# Nearest to a: putin, satyr, moussa, loves, bout, vendor, fy, micrometre,
# Nearest to the: appropriateness, troilus, vandals, verbal, flops, agesilaus, ltc, irrespective,
# Nearest to over: dismantle, prostrate, hughes, univ, gc, plymouth, philosophy, polydor,
# Nearest to would: orb, locomotion, gilgamesh, moravians, basics, advised, constitute, kaczynski,
# Nearest to more: daggers, sophistication, renounces, panini, venomous, oops, restored, faked,
# Nearest to while: dramas, lilac, architecture, effects, underworld, site, lazarus, amit,
# Nearest to may: lard, mahesh, maul, checkers, problematic, suarez, reactivated, stylish,
# Nearest to some: mcintyre, inconvenience, sincerely, bombings, aspiration, raza, reconciled, scholasticus,
# Nearest to have: ghulam, tina, asymmetrical, ginsberg, flickering, origami, coax, olives,
# Nearest to than: angrily, concordat, exorbitant, gesenius, hypertrophy, jonathon, pious, buds,
# Nearest to i: disturbances, ineffectual, elephant, ways, kora, kroon, catastrophic, triglycerides,
# Nearest to can: unexpectedly, gilead, damon, restored, cash, eldr, historiography, ideally,
# Nearest to th: miao, shedding, defaulted, byron, his, elegance, screw, prop,
# Nearest to for: flat, yorkist, insurgencies, kanal, unparalleled, archdukes, exploring, storming,
# Average loss at step 2000: 4.360255
# Average loss at step 4000: 3.856551
# Average loss at step 6000: 3.789448
# Average loss at step 8000: 3.683905
# Average loss at step 10000: 3.614458
# Nearest to history: franchised, mede, encyclop, omen, snake, lithosphere, angie, gonzalo,
# Nearest to had: was, has, have, congratulate, took, aurochs, touching, amnesia,
# Nearest to a: the, triode, this, vendor, medalist, it, prussia, any,
# Nearest to the: its, his, a, this, their, an, any, connacht,
# Nearest to over: polydor, ref, lotharingia, funniest, gc, apotheosis, beaten, baggins,
# Nearest to would: can, could, may, will, orb, must, hoisted, intuitionism,
# Nearest to more: daggers, subtypes, sophistication, imports, still, venomous, vote, restored,
# Nearest to while: dramas, decoders, site, architecture, recognition, goldwater, neberg, underworld,
# Nearest to may: can, could, would, eccentricity, retrieve, lard, maul, but,
# Nearest to some: many, mcintyre, seoul, bombings, tien, deterrent, villeneuve, axum,
# Nearest to have: had, has, were, be, soba, are, ghulam, catapult,
# Nearest to than: or, angrily, madrigal, support, appliance, like, vegetarians, treason,
# Nearest to i: caterpillar, ineffectual, kora, sdram, kroon, disturbances, cruciform, basso,
# Nearest to can: would, may, could, will, bookshop, however, aspiration, insurgents,
# Nearest to th: four, byron, miao, foot, murder, cathedrals, laminal, defaulted,
# Nearest to for: yorkist, perishable, kanal, with, malinche, in, option, collimated,
# Average loss at step 12000: 3.606623
# Average loss at step 14000: 3.570888
# Average loss at step 16000: 3.406886
# Average loss at step 18000: 3.453764
# Average loss at step 20000: 3.542865
# Nearest to history: angie, list, tapestry, mede, droplets, franchised, version, bundesl,
# Nearest to had: has, have, was, were, lanzarote, turner, xvii, congratulate,
# Nearest to a: triode, this, any, tractate, assortment, the, munition, having,
# Nearest to the: their, its, this, his, praise, these, revisited, some,
# Nearest to over: lotharingia, into, beaten, polydor, ref, funniest, johan, apotheosis,
# Nearest to would: could, can, may, will, should, must, might, orb,
# Nearest to more: less, daggers, most, unfamiliar, faked, handles, airtime, something,
# Nearest to while: when, delson, site, quartets, architecture, brood, recognition, dramas,
# Nearest to may: can, would, could, will, might, must, should, to,
# Nearest to some: many, several, these, their, deterrent, the, any, you,
# Nearest to have: had, has, were, be, are, coax, ping, soba,
# Nearest to than: or, madrigal, knight, appliance, trains, trafalgar, chekhov, falsehood,
# Nearest to i: caterpillar, we, ii, kora, consecration, elephant, joanna, iv,
# Nearest to can: would, may, could, will, should, must, might, bookshop,
# Nearest to th: byron, defaulted, laminal, miao, cathedrals, ambulatory, foot, lightsaber,
# Nearest to for: perishable, of, in, kanal, and, aurelian, by, malinche,
# Average loss at step 22000: 3.501192
# Average loss at step 24000: 3.486965
# Average loss at step 26000: 3.478963
# Average loss at step 28000: 3.479936
# Average loss at step 30000: 3.499849
# Nearest to history: list, jagan, droplets, version, angie, gossip, boulders, augustus,
# Nearest to had: has, have, was, were, having, since, xvii, jotham,
# Nearest to a: messina, any, benhavn, discordianism, arthurian, very, musket, medalist,
# Nearest to the: its, their, his, bibliographies, magnetization, any, her, praise,
# Nearest to over: into, beaten, lotharingia, polydor, funniest, reprint, johan, packard,
# Nearest to would: could, can, will, may, should, must, might, to,
# Nearest to more: less, most, daggers, multipliers, handles, very, brythonic, too,
# Nearest to while: when, although, delson, were, but, gained, could, inbound,
# Nearest to may: can, would, could, will, might, should, must, playwrights,
# Nearest to some: many, these, several, their, any, this, most, all,
# Nearest to have: had, has, are, be, were, having, include, regret,
# Nearest to than: or, appliance, much, madrigal, theodora, hefner, falsehood, disloyalty,
# Nearest to i: ii, we, caterpillar, you, kora, elephant, iv, iii,
# Nearest to can: may, would, could, will, should, must, might, cannot,
# Nearest to th: byron, eight, defaulted, ambulatory, lightsaber, laminal, miao, qf,
# Nearest to for: of, perishable, wiser, kanal, machete, artful, morphemes, valle,
# Average loss at step 32000: 3.496997
# Average loss at step 34000: 3.493982
# Average loss at step 36000: 3.454119
# Average loss at step 38000: 3.304291
# Average loss at step 40000: 3.431159
# Nearest to history: electrolyte, angie, jagan, list, classical, version, droplets, clinched,
# Nearest to had: has, have, was, were, since, did, arianism, eventually,
# Nearest to a: or, any, glare, hydrolysis, the, forestry, assortment, tractate,
# Nearest to the: its, this, their, curlers, his, a, any, livres,
# Nearest to over: into, packard, mancala, reprint, funniest, through, gorey, about,
# Nearest to would: could, can, will, may, should, must, might, did,
# Nearest to more: less, most, very, multipliers, fairly, faster, smaller, unfamiliar,
# Nearest to while: when, although, overpower, where, were, before, however, delson,
# Nearest to may: can, would, could, will, might, should, must, cannot,
# Nearest to some: many, these, any, several, their, both, ineffectual, other,
# Nearest to have: had, has, were, be, are, having, include, ghulam,
# Nearest to than: or, much, synchronization, madrigal, appliance, knight, shorthand, chocolat,
# Nearest to i: we, you, ii, caterpillar, t, they, he, masefield,
# Nearest to can: could, may, will, would, must, might, should, cannot,
# Nearest to th: byron, bc, defaulted, scalar, elegance, foot, ambulatory, qf,
# Nearest to for: if, when, in, kanal, malinche, with, yorkist, by,
# Average loss at step 42000: 3.433060
# Average loss at step 44000: 3.452891
# Average loss at step 46000: 3.450594
# Average loss at step 48000: 3.352725
# Average loss at step 50000: 3.382168
# Nearest to history: list, electrolyte, angie, jagan, classical, vhs, cameras, stringing,
# Nearest to had: has, have, were, was, having, eventually, makes, arianism,
# Nearest to a: any, another, arthurian, the, vendor, no, psp, lpc,
# Nearest to the: its, their, this, any, his, an, some, livres,
# Nearest to over: into, through, packard, funniest, about, gorey, jornal, reprint,
# Nearest to would: will, could, can, may, must, might, should, did,
# Nearest to more: less, most, fairly, very, faster, higher, longer, rather,
# Nearest to while: when, although, where, but, however, though, including, before,
# Nearest to may: can, would, could, will, might, should, must, cannot,
# Nearest to some: many, several, these, any, ineffectual, various, their, both,
# Nearest to have: had, were, has, are, be, having, include, who,
# Nearest to than: or, much, synchronization, knight, busby, boulevards, madrigal, trains,
# Nearest to i: you, we, ii, t, caterpillar, masefield, extracting, g,
# Nearest to can: could, may, will, would, must, might, should, cannot,
# Nearest to th: byron, defaulted, one, foot, ad, herbert, ambulatory, bc,
# Nearest to for: through, perishable, against, while, on, brubeck, malinche, of,
# Average loss at step 52000: 3.432789
# Average loss at step 54000: 3.424102
# Average loss at step 56000: 3.444520
# Average loss at step 58000: 3.397553
# Average loss at step 60000: 3.391936
# Nearest to history: list, origin, tapestry, classical, droplets, jagan, implementation, reminiscent,
# Nearest to had: has, have, was, were, having, been, pertains, gave,
# Nearest to a: the, any, another, lpc, assortment, arthurian, every, musically,
# Nearest to the: its, their, a, some, this, his, each, militar,
# Nearest to over: into, through, within, packard, about, funniest, jornal, styling,
# Nearest to would: could, will, may, can, must, might, should, did,
# Nearest to more: less, faster, fairly, most, very, longer, rather, smaller,
# Nearest to while: although, when, were, though, after, before, including, was,
# Nearest to may: can, would, could, will, might, should, must, cannot,
# Nearest to some: many, several, these, any, all, various, each, ineffectual,
# Nearest to have: had, has, are, were, be, having, produce, include,
# Nearest to than: much, or, and, but, chocolat, shorthand, boulevards, appliance,
# Nearest to i: you, ii, we, t, masefield, iii, caterpillar, they,
# Nearest to can: may, could, would, will, must, might, should, cannot,
# Nearest to th: eight, six, defaulted, five, bc, ad, four, nine,
# Nearest to for: of, when, if, and, shrapnel, to, including, malinche,
# Average loss at step 62000: 3.241496
# Average loss at step 64000: 3.251966
# Average loss at step 66000: 3.407086
# Average loss at step 68000: 3.398509
# Average loss at step 70000: 3.356961
# Nearest to history: list, praetorian, isles, tapestry, implementation, classical, reminiscent, period,
# Nearest to had: has, have, were, was, having, since, pertains, gave,
# Nearest to a: another, the, any, glare, every, medalist, monosyllabic, lpc,
# Nearest to the: its, their, any, these, a, this, some, militar,
# Nearest to over: packard, about, through, within, into, styling, under, enforcement,
# Nearest to would: will, could, may, can, might, must, should, did,
# Nearest to more: less, most, very, fairly, faster, longer, rather, too,
# Nearest to while: although, when, though, including, however, where, before, if,
# Nearest to may: can, would, could, will, might, must, should, cannot,
# Nearest to some: many, several, these, all, various, any, both, most,
# Nearest to have: had, has, were, are, having, include, provide, be,
# Nearest to than: or, and, much, but, synchronization, busby, shorthand, sufferer,
# Nearest to i: we, ii, you, g, they, he, ennedi, t,
# Nearest to can: may, could, would, will, might, must, cannot, should,
# Nearest to th: bc, ad, twentieth, bce, rd, foot, defaulted, herbert,
# Nearest to for: in, brubeck, including, platz, awa, invertible, wiser, if,
# Average loss at step 72000: 3.371530
# Average loss at step 74000: 3.348855
# Average loss at step 76000: 3.313566
# Average loss at step 78000: 3.352653
# Average loss at step 80000: 3.379751
# Nearest to history: isles, praetorian, list, cosmopolitan, tamers, classical, spirit, implementation,
# Nearest to had: has, have, were, was, having, began, pertains, been,
# Nearest to a: another, the, arthurian, every, dt, munition, levied, indeterminate,
# Nearest to the: tamm, its, a, this, their, his, magnetization, haznawi,
# Nearest to over: within, packard, through, into, about, styling, nailed, reprint,
# Nearest to would: will, could, might, may, can, must, should, did,
# Nearest to more: less, most, fairly, very, faster, daggers, too, rather,
# Nearest to while: although, when, though, including, but, before, after, are,
# Nearest to may: can, could, would, might, will, must, should, cannot,
# Nearest to some: many, several, various, most, any, numerous, these, both,
# Nearest to have: had, has, are, were, be, include, having, contain,
# Nearest to than: or, much, tax, boulevards, but, busby, and, somewhat,
# Nearest to i: you, we, ii, g, robotics, t, caterpillar, iii,
# Nearest to can: could, may, will, would, must, might, cannot, should,
# Nearest to th: bc, rd, twentieth, ad, eight, defaulted, five, herbert,
# Nearest to for: brubeck, malinche, platz, repetitive, thoughtful, shrapnel, wiser, machete,
# Average loss at step 82000: 3.409125
# Average loss at step 84000: 3.410832
# Average loss at step 86000: 3.385770
# Average loss at step 88000: 3.350969
# Average loss at step 90000: 3.358806
# Nearest to history: list, classical, isles, praetorian, philosophy, evaluation, consequences, origin,
# Nearest to had: has, have, was, were, having, pertains, started, began,
# Nearest to a: another, the, any, every, lpc, arthurian, styx, messina,
# Nearest to the: its, this, a, their, militar, another, his, livres,
# Nearest to over: within, through, packard, into, about, almost, eee, around,
# Nearest to would: could, will, might, can, may, must, should, did,
# Nearest to more: less, most, very, fairly, faster, rather, longer, too,
# Nearest to while: although, when, though, were, during, before, after, including,
# Nearest to may: can, could, would, might, should, will, must, cannot,
# Nearest to some: many, several, these, numerous, any, most, all, those,
# Nearest to have: had, has, are, were, be, having, include, provide,
# Nearest to than: much, or, synchronization, boulevards, tax, least, somewhat, busby,
# Nearest to i: we, ii, you, g, iii, t, n, rho,
# Nearest to can: may, could, might, will, would, must, cannot, should,
# Nearest to th: rd, seven, one, twentieth, ad, st, bce, bc,
# Nearest to for: of, including, against, when, geophysics, without, shrapnel, brubeck,
# Average loss at step 92000: 3.399909
# Average loss at step 94000: 3.255522
# Average loss at step 96000: 3.355122
# Average loss at step 98000: 3.244761
# Average loss at step 100000: 3.357080
# Nearest to history: list, isles, champs, classical, evaluation, praetorian, origin, collections,
# Nearest to had: has, have, was, having, were, makes, since, pertains,
# Nearest to a: another, any, the, arthurian, medalist, mathematik, particulars, glare,
# Nearest to the: their, its, his, your, her, a, s, this,
# Nearest to over: within, through, nailed, into, packard, capping, about, eee,
# Nearest to would: will, could, might, can, may, must, should, cannot,
# Nearest to more: less, most, fairly, very, faster, longer, extremely, larger,
# Nearest to while: when, although, though, including, and, after, before, were,
# Nearest to may: can, could, might, would, must, will, should, cannot,
# Nearest to some: many, several, any, these, numerous, those, all, various,
# Nearest to have: had, has, are, were, having, include, contain, provide,
# Nearest to than: or, much, least, synchronization, boulevards, madras, noses, and,
# Nearest to i: we, you, ii, they, wittelsbach, differentiates, t, v,
# Nearest to can: could, may, will, would, must, might, cannot, should,
# Nearest to th: rd, twentieth, nd, arlington, bc, defaulted, st, ad,
# Nearest to for: when, brubeck, without, if, geophysics, despite, platz, before,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to Word2Vec is called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
  data_index = 0
  batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
  print('\nwith bag_window = %d:' % (bag_window))  
  print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# ('data:', ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the'])
#
# with bag_window = 1:
# ('    batch:', [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']])
# ('    labels:', ['originated', 'as', 'a', 'term'])
#
# with bag_window = 2:
# ('    batch:', [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']])
# ('    labels:', ['as', 'a', 'term', 'of'])

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embeds, 1),
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.312515
# Nearest to its: druids, pew, winona, musical, erupt, revitalize, ideologically, halt,
# Nearest to they: tolerance, binghamton, caribou, dorff, escorts, yielding, older, romances,
# Nearest to of: oaths, splintered, autobiography, bribes, attribution, scavenge, levels, nests,
# Nearest to people: belief, hypothermia, clunies, seniority, arminianism, grabs, peril, ruthless,
# Nearest to use: oem, sees, diminishing, childbearing, holland, harappa, nantes, attachments,
# Nearest to th: patterns, billboards, isomers, tube, karmal, communion, aise, germania,
# Nearest to years: ecma, mongolia, angered, destruction, docetism, varphi, mad, reappear,
# Nearest to for: pinned, selfishness, xxiii, orthonormal, endured, hsieh, hsu, backing,
# Nearest to seven: smart, marysville, vagantes, carver, scully, precipitated, moralistic, blocked,
# Nearest to six: assassins, wikitravel, packard, member, rigorously, fads, hecht, bureau,
# Nearest to many: photos, slobodan, mazes, gigabytes, gatherer, aud, brochure, pumpkins,
# Nearest to from: covalently, dq, marcuse, unemployment, delphinus, councilor, hath, rewritable,
# Nearest to nine: moksha, interdependent, marl, mozambican, linea, introspective, rugova, busey,
# Nearest to with: electronvolt, porn, haile, wideawake, woodpecker, wealthiest, mnt, ericales,
# Nearest to be: gout, glass, contains, nightmarish, navarro, jobs, antiquated, aid,
# Nearest to as: injures, envisioned, jolla, slurs, consistency, sexist, clarified, reflects,
# Average loss at step 2000: 8.132425
# Average loss at step 4000: 5.120805
# Average loss at step 6000: 5.320661
# Average loss at step 8000: 4.636203
# Average loss at step 10000: 3.783018
# Nearest to its: their, his, the, bunyan, piped, a, boudica, digitized,
# Nearest to they: he, there, we, you, it, namely, patanjali, harburg,
# Nearest to of: for, hanna, musicologist, animations, industrialised, discharging, stimson, agincourt,
# Nearest to people: species, whorf, star, dysprosium, suites, submits, dosing, immortality,
# Nearest to use: exemplary, diminishing, pence, math, extramarital, interest, denoted, fredericksburg,
# Nearest to th: shoes, sarcasm, patterns, dcc, chesapeake, central, vegetable, axiomatic,
# Nearest to years: angered, kelly, otherwise, destruction, mad, year, time, blas,
# Nearest to for: of, protectorates, py, chaparral, under, schottky, unfulfilled, bayou,
# Nearest to seven: eight, nine, six, three, four, five, biopolymers, retitled,
# Nearest to six: eight, three, nine, five, four, seven, zero, serviced,
# Nearest to many: some, several, various, other, all, these, deficit, swain,
# Nearest to from: into, jelly, around, transfusion, fringes, ketones, politicians, prepare,
# Nearest to nine: eight, seven, six, zero, four, three, wooing, wootz,
# Nearest to with: after, cordite, bottoms, anhydrous, laundering, clowning, nourished, sucking,
# Nearest to be: refer, idolized, have, diffeomorphism, reassignment, pointless, wishful, pandemics,
# Nearest to as: devout, misleading, wimp, hangover, wildfire, thirty, kenjutsu, abstained,
# Average loss at step 12000: 3.885490
# Average loss at step 14000: 4.152265
# Average loss at step 16000: 4.361508
# Average loss at step 18000: 3.820073
# Average loss at step 20000: 3.752787
# Nearest to its: their, his, her, the, our, whose, fasces, awt,
# Nearest to they: we, there, you, these, he, she, harburg, it,
# Nearest to of: bestseller, hanna, wolfman, sher, overflows, for, maynooth, tremblay,
# Nearest to people: those, species, fluently, orcs, elamite, isopropyl, dysprosium, sicily,
# Nearest to use: regions, pence, contended, available, ask, refer, dorian, ayin,
# Nearest to th: intent, names, madagascar, race, st, approximately, archival, promoted,
# Nearest to years: months, year, mad, children, thousand, kelly, realignment, angered,
# Nearest to for: after, py, yf, rainbows, before, crescas, of, when,
# Nearest to seven: six, eight, five, three, four, nine, two, zero,
# Nearest to six: seven, four, eight, five, three, nine, two, fingertips,
# Nearest to many: some, several, various, most, all, both, those, mascot,
# Nearest to from: into, during, through, using, universality, without, jelly, kleist,
# Nearest to nine: eight, seven, six, zero, five, three, two, dcc,
# Nearest to with: between, bottoms, primers, when, while, bostonians, spikes, rating,
# Nearest to be: refer, being, idolized, is, ambiguously, linebarger, lead, wishful,
# Nearest to as: elca, wimp, devout, melody, kenjutsu, dbv, beacons, bourgeois,
# Average loss at step 22000: 3.682430
# Average loss at step 24000: 3.633856
# Average loss at step 26000: 3.816109
# Average loss at step 28000: 3.615266
# Average loss at step 30000: 3.440345
# Nearest to its: their, his, the, her, our, whose, recounting, sequential,
# Nearest to they: we, there, he, these, she, litigated, vain, reptilian,
# Nearest to of: for, in, during, animations, musicologist, centaur, before, wolfman,
# Nearest to people: tribes, members, men, species, those, ships, lubricant, architects,
# Nearest to use: interest, globalization, catalysis, formation, maharaja, zeppo, cushion, dorian,
# Nearest to th: nd, nine, intent, investigative, twentieth, apologetic, patterns, st,
# Nearest to years: months, decades, days, centuries, year, times, hours, kelly,
# Nearest to for: of, after, mages, woodcock, before, bird, tanakh, spinoff,
# Nearest to seven: five, six, four, three, nine, zero, eight, excavating,
# Nearest to six: five, seven, three, nine, four, eight, two, lal,
# Nearest to many: several, some, various, few, these, certain, all, those,
# Nearest to from: through, into, using, jelly, hammersmith, labarum, narayana, undecidable,
# Nearest to nine: eight, act, another, islands, f, joker, js, n,
# Nearest to with: between, primers, after, sitter, while, among, bashing, bottoms,
# Nearest to be: refer, being, lead, idolized, produce, stand, provide, wishful,
# Nearest to as: wildfire, became, isometric, wimp, lemmink, like, nne, itasca,
# Average loss at step 32000: 3.229586
# Average loss at step 34000: 3.427865
# Average loss at step 36000: 3.382748
# Average loss at step 38000: 3.396016
# Average loss at step 40000: 3.307234
# Nearest to its: their, his, her, the, ejective, recounting, whose, your,
# Nearest to they: we, there, she, he, textured, connemara, superclass, these,
# Nearest to of: within, throughout, including, jens, hanna, stimson, decorum, between,
# Nearest to people: men, residents, those, writers, members, tribes, words, man,
# Nearest to use: filler, because, find, choose, malaise, repay, think, ladoga,
# Nearest to th: nd, twentieth, rd, munch, st, nineteenth, umpire, apologetic,
# Nearest to years: decades, months, days, centuries, year, hours, realignment, lapd,
# Nearest to for: after, without, protectorates, yf, clogged, heyday, iigs, toward,
# Nearest to seven: eight, five, six, four, three, zero, nine, mev,
# Nearest to six: five, four, eight, seven, three, dor, amok, numerous,
# Nearest to many: some, several, various, both, these, multiple, certain, all,
# Nearest to from: into, through, including, using, dictation, between, across, delphinus,
# Nearest to nine: eight, dcc, seven, december, august, september, dreidel, november,
# Nearest to with: between, primers, clowning, among, while, using, sitter, without,
# Nearest to be: refer, idolized, being, lead, produce, been, remain, exist,
# Nearest to as: dbv, depressing, outposts, qm, wildfire, became, devout, ij,
# Average loss at step 42000: 3.317319
# Average loss at step 44000: 3.276811
# Average loss at step 46000: 3.275677
# Average loss at step 48000: 3.148247
# Average loss at step 50000: 3.150397
# Nearest to its: their, his, the, her, our, your, jonathan, heydrich,
# Nearest to they: we, he, she, there, you, dems, it, connemara,
# Nearest to of: hanna, including, jens, musicologist, during, following, hingis, sims,
# Nearest to people: men, person, members, residents, women, individuals, them, man,
# Nearest to use: practice, allow, zeppo, importance, biotechnology, implementation, crystallization, repay,
# Nearest to th: nd, twentieth, rd, st, nineteenth, katy, enlists, filthy,
# Nearest to years: days, decades, months, centuries, year, hours, minutes, times,
# Nearest to for: protectorates, when, after, gherkin, parcels, marietta, boulevard, galapagos,
# Nearest to seven: eight, six, five, three, nine, four, zero, iy,
# Nearest to six: five, seven, three, eight, four, nine, zero, danorum,
# Nearest to many: some, several, various, most, all, certain, thousands, few,
# Nearest to from: into, during, across, through, universality, within, when, in,
# Nearest to nine: eight, seven, six, five, dcc, vol, august, zero,
# Nearest to with: between, introduces, among, electronvolt, attainment, comp, having, has,
# Nearest to be: being, refer, lead, produce, idolized, remain, provide, mean,
# Nearest to as: qm, lemmink, airy, repainted, stepson, healer, pesky, melody,
# Average loss at step 52000: 3.207944
# Average loss at step 54000: 3.232439
# Average loss at step 56000: 3.041807
# Average loss at step 58000: 3.158145
# Average loss at step 60000: 3.134242
# Nearest to its: their, his, her, the, our, my, contending, a,
# Nearest to they: we, you, he, there, she, vain, others, litigated,
# Nearest to of: including, jens, thr, represents, germination, malaysian, industrialised, centaur,
# Nearest to people: peoples, person, tribes, species, members, those, communities, fluently,
# Nearest to use: allow, approach, practice, measure, cushion, cause, stole, damin,
# Nearest to th: nd, twentieth, st, rd, nineteenth, eighteenth, katy, glut,
# Nearest to years: months, decades, days, centuries, year, hours, weeks, versions,
# Nearest to for: crochet, amok, auger, chi, plotinus, copula, bnp, keaton,
# Nearest to seven: six, eight, five, three, four, zero, nine, two,
# Nearest to six: seven, five, four, eight, three, nine, zero, two,
# Nearest to many: some, several, numerous, various, all, few, both, most,
# Nearest to from: during, into, under, contra, noticeably, jelly, through, rewritable,
# Nearest to nine: eight, seven, six, zero, five, september, dcc, november,
# Nearest to with: between, primers, among, via, arabica, saw, clowning, comparably,
# Nearest to be: refer, remain, lead, being, exist, produce, become, have,
# Nearest to as: isometric, repainted, healer, lemmink, prostaglandin, itasca, stepson, melody,
# Average loss at step 62000: 3.119757
# Average loss at step 64000: 2.995317
# Average loss at step 66000: 3.391947
# Average loss at step 68000: 3.098154
# Average loss at step 70000: 3.107024
# Nearest to its: their, his, her, the, our, ejective, your, androgen,
# Nearest to they: we, you, he, there, she, virginity, ard, textured,
# Nearest to of: including, despite, hanna, hammerhead, in, exuberance, during, throughout,
# Nearest to people: children, person, men, women, individuals, students, jews, peoples,
# Nearest to use: allow, make, rightness, cause, transplant, speak, transport, cushion,
# Nearest to th: nd, twentieth, rd, nineteenth, st, revamped, eighteenth, katy,
# Nearest to years: decades, months, days, year, centuries, minutes, hours, versions,
# Nearest to for: tagging, or, bicycling, plotinus, via, however, essences, wearable,
# Nearest to seven: six, five, eight, three, four, zero, bohm, essential,
# Nearest to six: seven, five, three, four, eight, two, zero, fingertips,
# Nearest to many: crochet, chekhov, auger, amok, ahmad, electron, chi, copula,
# Nearest to from: through, into, contra, before, beyond, during, without, delphinus,
# Nearest to nine: eight, peerages, rfc, ssbn, shahi, maaouya, berthe, th,
# Nearest to with: between, among, primers, when, without, via, arabica, saw,
# Nearest to be: exist, remain, idolized, refer, being, produce, get, lead,
# Nearest to as: repainted, isometric, cyclist, bottles, lace, healer, hybridization, wildfire,
# Average loss at step 72000: 3.002693
# Average loss at step 74000: 2.964392
# Average loss at step 76000: 3.096920
# Average loss at step 78000: 3.073390
# Average loss at step 80000: 2.920506
# Nearest to its: their, his, our, your, ejective, whose, the, sissy,
# Nearest to they: we, you, there, she, these, aroused, it, connemara,
# Nearest to of: throughout, kessler, including, centaur, wearable, malaysian, jens, following,
# Nearest to people: women, person, men, individuals, jews, children, students, writers,
# Nearest to use: sense, help, importance, provide, want, auteurs, stand, applications,
# Nearest to th: st, twentieth, nd, nine, nineteenth, third, eighteenth, rd,
# Nearest to years: decades, months, year, centuries, days, minutes, hours, seconds,
# Nearest to for: behind, without, protectorates, gherkin, mages, broadsheet, clogged, galapagos,
# Nearest to seven: eight, four, five, three, six, zero, nine, gillies,
# Nearest to six: four, five, seven, three, guinness, lee, color, orchestra,
# Nearest to many: some, several, numerous, all, various, most, certain, thousands,
# Nearest to from: through, beyond, into, across, anastasia, ibizan, including, during,
# Nearest to nine: eight, six, th, seven, zero, four, september, five,
# Nearest to with: between, among, primers, via, clowning, without, josephine, while,
# Nearest to be: refer, lead, remain, occur, represent, produce, develop, become,
# Nearest to as: repainted, worry, airy, isometric, itasca, protectorates, brummell, melody,
# Average loss at step 82000: 3.002655
# Average loss at step 84000: 2.951298
# Average loss at step 86000: 2.973232
# Average loss at step 88000: 3.053587
# Average loss at step 90000: 2.905971
# Nearest to its: his, their, the, her, our, s, your, transfusions,
# Nearest to they: amok, hearst, crochet, corporation, chekhov, hm, lee, auger,
# Nearest to of: including, jens, following, include, musicologist, for, despite, centaur,
# Nearest to people: tribes, jews, men, citizens, peoples, children, person, those,
# Nearest to use: choice, rightness, list, support, amount, cushion, because, introduction,
# Nearest to th: twentieth, nd, st, nineteenth, eighteenth, third, nine, rd,
# Nearest to years: decades, months, days, centuries, year, weeks, hours, minutes,
# Nearest to for: after, pinned, realplayer, of, gherkin, protectorates, spikes, essences,
# Nearest to seven: six, eight, four, five, nine, three, zero, two,
# Nearest to six: four, seven, eight, five, three, zero, nine, two,
# Nearest to many: various, some, both, numerous, chekhov, they, hm, lace,
# Nearest to from: lace, whose, rapidly, tories, crochet, nw, outcasts, hearst,
# Nearest to nine: seven, eight, six, four, late, th, mid, zero,
# Nearest to with: between, bottoms, via, when, among, without, josephine, primers,
# Nearest to be: refer, being, represent, lead, occur, remain, produce, get,
# Nearest to as: outposts, repainted, worry, itasca, dbv, like, marcuse, leach,
# Average loss at step 92000: 2.984245
# Average loss at step 94000: 2.947096
# Average loss at step 96000: 2.791370
# Average loss at step 98000: 2.504216
# Average loss at step 100000: 2.821357
# Nearest to its: his, their, her, the, our, contending, your, largely,
# Nearest to they: we, you, he, there, she, textured, harburg, asymptotic,
# Nearest to of: dorn, represents, including, in, jens, hanna, centaur, considers,
# Nearest to people: men, children, women, individuals, peoples, citizens, person, tribes,
# Nearest to use: list, stand, using, add, ownership, value, change, target,
# Nearest to th: nd, twentieth, st, nineteenth, eighteenth, rd, third, tenth,
# Nearest to years: decades, months, days, year, centuries, hours, minutes, weeks,
# Nearest to for: without, after, protectorates, gherkin, iigs, yf, marietta, boulevard,
# Nearest to seven: six, hearst, crochet, randolph, auger, lee, amok, corporation,
# Nearest to six: seven, crochet, hearst, auger, randolph, amok, lee, tora,
# Nearest to many: some, several, various, numerous, both, multiple, thousands, few,
# Nearest to from: into, through, via, across, anastasia, beyond, in, swears,
# Nearest to nine: eight, seven, six, zero, nm, color, joker, criticises,
# Nearest to with: between, via, among, bottoms, gerais, primers, without, publ,
# Nearest to be: remain, being, refer, lead, occur, exist, serve, produce,
# Nearest to as: worry, melody, itasca, leach, bedouin, despite, lace, claypool,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
