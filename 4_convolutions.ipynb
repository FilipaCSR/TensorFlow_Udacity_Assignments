# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# ('Training set', (200000, 28, 28), (200000,))
# ('Validation set', (10000, 28, 28), (10000,))
# ('Test set', (10000, 28, 28), (10000,))

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# ('Training set', (200000, 28, 28, 1), (200000, 10))
# ('Validation set', (10000, 28, 28, 1), (10000, 10))
# ('Test set', (10000, 28, 28, 1), (10000, 10))

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  #tf.nn.conv2d(input, filter, [1,strides, strides, 1], padding)
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.205263
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.681542
# Minibatch accuracy: 37.5%
# Validation accuracy: 38.6%
# Minibatch loss at step 100: 0.635623
# Minibatch accuracy: 87.5%
# Validation accuracy: 50.9%
# Minibatch loss at step 150: 1.057903
# Minibatch accuracy: 68.8%
# Validation accuracy: 53.6%
# Minibatch loss at step 200: 0.844060
# Minibatch accuracy: 75.0%
# Validation accuracy: 59.6%
# Minibatch loss at step 250: 1.025052
# Minibatch accuracy: 68.8%
# Validation accuracy: 61.0%
# Minibatch loss at step 300: 0.347634
# Minibatch accuracy: 87.5%
# Validation accuracy: 62.4%
# Minibatch loss at step 350: 0.244771
# Minibatch accuracy: 100.0%
# Validation accuracy: 62.1%
# Minibatch loss at step 400: 0.455430
# Minibatch accuracy: 87.5%
# Validation accuracy: 62.6%
# Minibatch loss at step 450: 0.713693
# Minibatch accuracy: 75.0%
# Validation accuracy: 64.1%
# Minibatch loss at step 500: 0.612335
# Minibatch accuracy: 81.2%
# Validation accuracy: 63.5%
# Minibatch loss at step 550: 0.731780
# Minibatch accuracy: 81.2%
# Validation accuracy: 66.4%
# Minibatch loss at step 600: 0.474741
# Minibatch accuracy: 87.5%
# Validation accuracy: 65.3%
# Minibatch loss at step 650: 0.451357
# Minibatch accuracy: 81.2%
# Validation accuracy: 65.7%
# Minibatch loss at step 700: 0.485293
# Minibatch accuracy: 81.2%
# Validation accuracy: 66.1%
# Minibatch loss at step 750: 0.350562
# Minibatch accuracy: 81.2%
# Validation accuracy: 67.3%
# Minibatch loss at step 800: 0.805696
# Minibatch accuracy: 81.2%
# Validation accuracy: 65.2%
# Minibatch loss at step 850: 0.485235
# Minibatch accuracy: 87.5%
# Validation accuracy: 67.7%
# Minibatch loss at step 900: 0.782385
# Minibatch accuracy: 87.5%
# Validation accuracy: 68.9%
# Minibatch loss at step 950: 0.178859
# Minibatch accuracy: 100.0%
# Validation accuracy: 67.6%
# Minibatch loss at step 1000: 0.826024
# Minibatch accuracy: 75.0%
# Validation accuracy: 67.2%
# Test accuracy: 89.5%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  #tf.nn.max_pool(input,ksize, strides, padding)
  #[1, 1, 1, 1] -> no strides  
  def model(data):
    
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1],strides=[1, 2, 2, 1], padding='SAME')
    
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1],strides=[1, 2, 2, 1], padding='SAME')

    shape = pool.get_shape().as_list()
    reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    
    return tf.matmul(hidden, layer4_weights) + layer4_biases
    
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.437686
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.014871
# Minibatch accuracy: 31.2%
# Validation accuracy: 36.4%
# Minibatch loss at step 100: 0.853462
# Minibatch accuracy: 75.0%
# Validation accuracy: 45.7%
# Minibatch loss at step 150: 1.087946
# Minibatch accuracy: 62.5%
# Validation accuracy: 53.0%
# Minibatch loss at step 200: 0.815565
# Minibatch accuracy: 81.2%
# Validation accuracy: 59.7%
# Minibatch loss at step 250: 1.102759
# Minibatch accuracy: 62.5%
# Validation accuracy: 62.5%
# Minibatch loss at step 300: 0.370984
# Minibatch accuracy: 93.8%
# Validation accuracy: 64.4%
# Minibatch loss at step 350: 0.336737
# Minibatch accuracy: 87.5%
# Validation accuracy: 63.2%
# Minibatch loss at step 400: 0.341391
# Minibatch accuracy: 87.5%
# Validation accuracy: 62.6%
# Minibatch loss at step 450: 0.664897
# Minibatch accuracy: 75.0%
# Validation accuracy: 67.0%
# Minibatch loss at step 500: 0.493332
# Minibatch accuracy: 87.5%
# Validation accuracy: 67.8%
# Minibatch loss at step 550: 0.787876
# Minibatch accuracy: 75.0%
# Validation accuracy: 68.1%
# Minibatch loss at step 600: 0.419036
# Minibatch accuracy: 87.5%
# Validation accuracy: 69.3%
# Minibatch loss at step 650: 0.493290
# Minibatch accuracy: 81.2%
# Validation accuracy: 69.1%
# Minibatch loss at step 700: 0.465774
# Minibatch accuracy: 87.5%
# Validation accuracy: 70.5%
# Minibatch loss at step 750: 0.365566
# Minibatch accuracy: 93.8%
# Validation accuracy: 69.9%
# Minibatch loss at step 800: 1.004506
# Minibatch accuracy: 75.0%
# Validation accuracy: 66.4%
# Minibatch loss at step 850: 0.396093
# Minibatch accuracy: 81.2%
# Validation accuracy: 70.1%
# Minibatch loss at step 900: 0.892428
# Minibatch accuracy: 81.2%
# Validation accuracy: 71.6%
# Minibatch loss at step 950: 0.146943
# Minibatch accuracy: 100.0%
# Validation accuracy: 70.4%
# Minibatch loss at step 1000: 0.573795
# Minibatch accuracy: 81.2%
# Validation accuracy: 69.7%
# Test accuracy: 90.4%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %% [markdown]
# - > Add dropout (with keep_prob = 0.9)
# - > Increase number of steps (1001 - 2001)

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  #tf.nn.max_pool(input,ksize, strides, padding)
  #[1, 1, 1, 1] -> no strides  
  def model(data, train):
    
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1],strides=[1, 2, 2, 1], padding='SAME')
    
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1],strides=[1, 2, 2, 1], padding='SAME')

    shape = pool.get_shape().as_list()
    reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    
    #Add dropout (only to the train dataset)
    if train:
        hidden = tf.nn.dropout(hidden, 0.9)
        
    return tf.matmul(hidden, layer4_weights) + layer4_biases
    
  # Training computation.
  logits = model(tf_train_dataset, train = True)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
 
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset, train = False))
  test_prediction = tf.nn.softmax(model(tf_test_dataset, train = False))

# %%
num_steps = 2001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 4.911012
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.964759
# Minibatch accuracy: 37.5%
# Validation accuracy: 34.6%
# Minibatch loss at step 100: 1.204821
# Minibatch accuracy: 68.8%
# Validation accuracy: 46.1%
# Minibatch loss at step 150: 1.013251
# Minibatch accuracy: 75.0%
# Validation accuracy: 46.9%
# Minibatch loss at step 200: 0.860857
# Minibatch accuracy: 75.0%
# Validation accuracy: 55.8%
# Minibatch loss at step 250: 1.207080
# Minibatch accuracy: 75.0%
# Validation accuracy: 59.0%
# Minibatch loss at step 300: 0.372835
# Minibatch accuracy: 87.5%
# Validation accuracy: 64.2%
# Minibatch loss at step 350: 0.186927
# Minibatch accuracy: 93.8%
# Validation accuracy: 62.2%
# Minibatch loss at step 400: 0.430277
# Minibatch accuracy: 87.5%
# Validation accuracy: 63.6%
# Minibatch loss at step 450: 0.699373
# Minibatch accuracy: 75.0%
# Validation accuracy: 64.8%
# Minibatch loss at step 500: 0.826410
# Minibatch accuracy: 75.0%
# Validation accuracy: 66.5%
# Minibatch loss at step 550: 0.651612
# Minibatch accuracy: 87.5%
# Validation accuracy: 66.2%
# Minibatch loss at step 600: 0.661204
# Minibatch accuracy: 81.2%
# Validation accuracy: 68.2%
# Minibatch loss at step 650: 0.524421
# Minibatch accuracy: 81.2%
# Validation accuracy: 68.2%
# Minibatch loss at step 700: 0.547715
# Minibatch accuracy: 81.2%
# Validation accuracy: 68.2%
# Minibatch loss at step 750: 0.349850
# Minibatch accuracy: 93.8%
# Validation accuracy: 69.1%
# Minibatch loss at step 800: 1.036027
# Minibatch accuracy: 81.2%
# Validation accuracy: 65.2%
# Minibatch loss at step 850: 0.380493
# Minibatch accuracy: 87.5%
# Validation accuracy: 70.0%
# Minibatch loss at step 900: 0.889844
# Minibatch accuracy: 87.5%
# Validation accuracy: 71.3%
# Minibatch loss at step 950: 0.244465
# Minibatch accuracy: 93.8%
# Validation accuracy: 68.4%
# Minibatch loss at step 1000: 0.930242
# Minibatch accuracy: 75.0%
# Validation accuracy: 70.0%
# Minibatch loss at step 1050: 1.106113
# Minibatch accuracy: 75.0%
# Validation accuracy: 70.6%
# Minibatch loss at step 1100: 1.019563
# Minibatch accuracy: 81.2%
# Validation accuracy: 70.1%
# Minibatch loss at step 1150: 0.150172
# Minibatch accuracy: 93.8%
# Validation accuracy: 71.2%
# Minibatch loss at step 1200: 0.188589
# Minibatch accuracy: 93.8%
# Validation accuracy: 68.7%
# Minibatch loss at step 1250: 0.905551
# Minibatch accuracy: 75.0%
# Validation accuracy: 71.2%
# Minibatch loss at step 1300: 0.787439
# Minibatch accuracy: 75.0%
# Validation accuracy: 69.9%
# Minibatch loss at step 1350: 0.354191
# Minibatch accuracy: 87.5%
# Validation accuracy: 70.2%
# Minibatch loss at step 1400: 0.828864
# Minibatch accuracy: 68.8%
# Validation accuracy: 71.2%
# Minibatch loss at step 1450: 0.178240
# Minibatch accuracy: 87.5%
# Validation accuracy: 71.7%
# Minibatch loss at step 1500: 0.305169
# Minibatch accuracy: 87.5%
# Validation accuracy: 71.8%
# Minibatch loss at step 1550: 0.166091
# Minibatch accuracy: 93.8%
# Validation accuracy: 70.9%
# Minibatch loss at step 1600: 1.027558
# Minibatch accuracy: 75.0%
# Validation accuracy: 72.9%
# Minibatch loss at step 1650: 0.234751
# Minibatch accuracy: 93.8%
# Validation accuracy: 73.1%
# Minibatch loss at step 1700: 0.746480
# Minibatch accuracy: 81.2%
# Validation accuracy: 72.2%
# Minibatch loss at step 1750: 0.267603
# Minibatch accuracy: 87.5%
# Validation accuracy: 73.1%
# Minibatch loss at step 1800: 0.428088
# Minibatch accuracy: 87.5%
# Validation accuracy: 71.4%
# Minibatch loss at step 1850: 0.016280
# Minibatch accuracy: 100.0%
# Validation accuracy: 72.6%
# Minibatch loss at step 1900: 0.550127
# Minibatch accuracy: 81.2%
# Validation accuracy: 72.1%
# Minibatch loss at step 1950: 0.394033
# Minibatch accuracy: 87.5%
# Validation accuracy: 73.3%
# Minibatch loss at step 2000: 1.093676
# Minibatch accuracy: 62.5%
# Validation accuracy: 72.8%
# Test accuracy: 92.1%

# %% [markdown]
# - > adding learning rate decay
# - > keep dropout

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  #tf.nn.max_pool(input,ksize, strides, padding)
  #[1, 1, 1, 1] -> no strides  
  def model(data, train):
    
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1],strides=[1, 2, 2, 1], padding='SAME')
    
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1],strides=[1, 2, 2, 1], padding='SAME')

    shape = pool.get_shape().as_list()
    reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)

     #Add dropout (only to the train dataset)
    if train:
        hidden = tf.nn.dropout(hidden, 0.9)
        
    return tf.matmul(hidden, layer4_weights) + layer4_biases
    
  # Training computation.
  logits = model(tf_train_dataset, train = True)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  global_step = tf.Variable(0)
  starter_learning_rate = 0.1
  learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step, 2000, 0.90)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
 
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset, train = False))
  test_prediction = tf.nn.softmax(model(tf_test_dataset, train = False))

# %%
num_steps = 2001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.863290
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.308521
# Minibatch accuracy: 12.5%
# Validation accuracy: 15.5%
# Minibatch loss at step 100: 2.067043
# Minibatch accuracy: 25.0%
# Validation accuracy: 29.6%
# Minibatch loss at step 150: 1.173930
# Minibatch accuracy: 68.8%
# Validation accuracy: 41.5%
# Minibatch loss at step 200: 0.886297
# Minibatch accuracy: 68.8%
# Validation accuracy: 53.6%
# Minibatch loss at step 250: 0.969561
# Minibatch accuracy: 62.5%
# Validation accuracy: 59.3%
# Minibatch loss at step 300: 0.399468
# Minibatch accuracy: 93.8%
# Validation accuracy: 63.2%
# Minibatch loss at step 350: 0.326065
# Minibatch accuracy: 87.5%
# Validation accuracy: 63.4%
# Minibatch loss at step 400: 0.530688
# Minibatch accuracy: 87.5%
# Validation accuracy: 65.5%
# Minibatch loss at step 450: 0.757801
# Minibatch accuracy: 75.0%
# Validation accuracy: 67.0%
# Minibatch loss at step 500: 0.773165
# Minibatch accuracy: 75.0%
# Validation accuracy: 66.8%
# Minibatch loss at step 550: 0.746551
# Minibatch accuracy: 75.0%
# Validation accuracy: 67.3%
# Minibatch loss at step 600: 0.471105
# Minibatch accuracy: 75.0%
# Validation accuracy: 67.5%
# Minibatch loss at step 650: 0.588925
# Minibatch accuracy: 87.5%
# Validation accuracy: 69.0%
# Minibatch loss at step 700: 0.492761
# Minibatch accuracy: 81.2%
# Validation accuracy: 69.3%
# Minibatch loss at step 750: 0.359401
# Minibatch accuracy: 87.5%
# Validation accuracy: 70.5%
# Minibatch loss at step 800: 1.038079
# Minibatch accuracy: 75.0%
# Validation accuracy: 68.0%
# Minibatch loss at step 850: 0.509283
# Minibatch accuracy: 87.5%
# Validation accuracy: 69.4%
# Minibatch loss at step 900: 0.960082
# Minibatch accuracy: 81.2%
# Validation accuracy: 70.8%
# Minibatch loss at step 950: 0.282864
# Minibatch accuracy: 93.8%
# Validation accuracy: 70.0%
# Minibatch loss at step 1000: 0.852011
# Minibatch accuracy: 68.8%
# Validation accuracy: 70.3%
# Minibatch loss at step 1050: 0.721400
# Minibatch accuracy: 75.0%
# Validation accuracy: 72.3%
# Minibatch loss at step 1100: 0.814994
# Minibatch accuracy: 81.2%
# Validation accuracy: 72.2%
# Minibatch loss at step 1150: 0.230401
# Minibatch accuracy: 93.8%
# Validation accuracy: 70.2%
# Minibatch loss at step 1200: 0.217389
# Minibatch accuracy: 93.8%
# Validation accuracy: 71.3%
# Minibatch loss at step 1250: 1.134854
# Minibatch accuracy: 75.0%
# Validation accuracy: 72.9%
# Minibatch loss at step 1300: 0.501055
# Minibatch accuracy: 81.2%
# Validation accuracy: 72.6%
# Minibatch loss at step 1350: 0.310371
# Minibatch accuracy: 87.5%
# Validation accuracy: 72.5%
# Minibatch loss at step 1400: 1.070058
# Minibatch accuracy: 68.8%
# Validation accuracy: 69.9%
# Minibatch loss at step 1450: 0.197752
# Minibatch accuracy: 93.8%
# Validation accuracy: 72.1%
# Minibatch loss at step 1500: 0.358896
# Minibatch accuracy: 87.5%
# Validation accuracy: 71.6%
# Minibatch loss at step 1550: 0.196273
# Minibatch accuracy: 93.8%
# Validation accuracy: 72.5%
# Minibatch loss at step 1600: 1.127390
# Minibatch accuracy: 75.0%
# Validation accuracy: 74.2%
# Minibatch loss at step 1650: 0.248100
# Minibatch accuracy: 93.8%
# Validation accuracy: 71.4%
# Minibatch loss at step 1700: 0.984652
# Minibatch accuracy: 75.0%
# Validation accuracy: 73.1%
# Minibatch loss at step 1750: 0.160287
# Minibatch accuracy: 93.8%
# Validation accuracy: 73.6%
# Minibatch loss at step 1800: 0.485405
# Minibatch accuracy: 87.5%
# Validation accuracy: 73.6%
# Minibatch loss at step 1850: 0.005729
# Minibatch accuracy: 100.0%
# Validation accuracy: 73.0%
# Minibatch loss at step 1900: 0.388613
# Minibatch accuracy: 75.0%
# Validation accuracy: 73.6%
# Minibatch loss at step 1950: 0.559493
# Minibatch accuracy: 93.8%
# Validation accuracy: 74.2%
# Minibatch loss at step 2000: 0.812123
# Minibatch accuracy: 68.8%
# Validation accuracy: 73.8%
# Test accuracy: 92.7%
